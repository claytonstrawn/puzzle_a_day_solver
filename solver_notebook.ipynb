# %%
from solver import solve_board
#from Board import Board

solve_board(date = ('June',30),allow_flips=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       1 from solver import solve_board
#       2 #from Board import Board
# ----> 4 solve_board(date = ('June',30),allow_flips=True)
#
# File ~/puzzle_a_day_solver/solver.py:21, in solve_board(date, board, allow_flips, take_first, verbose, plot_solution, archived_solutions)
#      19     out_name = 'archived_solutions/flips_full_solutions.pickle'
#      20 with open(out_name, 'rb') as dbfile:
# ---> 21     output = pickle.load(dbfile)[date][0]
#      22     if len(output) == 0:
#      23         output = None
#
# AttributeError: Can't get attribute 'Board' on <module '__main__'>

# %%
import pickle
from Board import Board
from plotting import plot_board
with open('archived_solutions/noflips_full_solutions.pickle', 'rb') as dbfile:
    loaded = pickle.load(dbfile)
b = loaded['July',21][0][0]
plot_board(b)

# %%
b = loaded['July',21]
b
# Out:
# ([<Board.Board at 0x7f86f051e940>],
#  6266,
#  datetime.timedelta(seconds=2, microseconds=491280))
